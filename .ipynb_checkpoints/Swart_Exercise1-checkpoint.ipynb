# %% [markdown]
# # The upper ocean mixed layer

# %% [markdown]
# #### Load packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(10,8)

# %% [markdown]
# #### Load data

# %%
data_dir='/home/wizard/Documents/observing_the_ocean/swart/exercises/Exercise1/'

# %%
import scipy.io as spio
dat=spio.loadmat(data_dir+'Swart_ex1_MIMOCdata.mat')

# %%
temp=dat['temp']
depth=dat['depth'].flatten()

# %% [markdown]
# #### Compute MLD

# %%
def mld_calc(temp,depth):
    return depth[(abs((temp-temp[10]))>=0.2)].min()

# %%
#### compute mld using temperature threshold of 0.2C
mld = np.array([mld_calc(x,depth) for x in temp])
mld
# Out:
# array([ 43,  53,  66,  80,  94, 111, 106, 114, 114,  92, 122,  42])

# %%
##### plot temperature profiles with MLD overlain
months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sept','Oct','Nov','Dec']
fig,ax=plt.subplots(4,3,figsize=[12,8],gridspec_kw=dict(hspace=0.5),sharex=True,sharey=True)
fig.suptitle('Temperature profile') 
fig.text(0.5, 0.04, 'Temperature ($^o$C)', ha='center', va='center')
fig.text(0.06, 0.5, 'Depth (m)', ha='center', va='center', rotation='vertical')

targets=zip(ax.flatten(),np.arange(12),months)
for i, (axe,x,mon) in enumerate(targets):
    axe.plot(temp[i],depth*-1)
    axe.axhline(mld[i]*-1,linestyle='--',c='Grey')
    axe.set_ylim(-300,0)
    axe.set_title('{}'.format(months[i]))

# %%
# compute heat content
dens=1025
cp=4217
Heat=dens*cp*np.sum((temp+273.15),axis=1)

# %%
plt.plot(Heat)
plt.ylabel('Heat Content [J.m$^2$]')
plt.xlabel('Months')
# Out:
# Text(0.5,0,'Months')

# %%
delH=(Heat[1:]-Heat[:-1])/(3600*24*30) #change in Q over time
plt.ylabel('Heat Flux [J.m$^2$]')
plt.xlabel('Months')
plt.plot(delH)

# %%
#temperature change
delta_T=np.asarray(delH)/(cp*dens*np.asarray(mld[1:]))

# %%
plt.plot(delta_T)
plt.ylabel('Temperature change [$^o$C]')
plt.xlabel('Months')
# Out:
# Text(0.5,0,'Months')

# %%
#temp of mixed layer
delta_T_actual=temp[1:,10]-temp[:-1,10]
plt.plot(delta_T_actual)
plt.ylabel('Temperature change [$^o$C]')
plt.xlabel('Months')
# Out:
# Text(0.5,0,'Months')

# %%
deficit=delta_T-delta_T_actual
plt.plot(deficit)
plt.ylabel('Temperature deficit [$^o$C]')
plt.xlabel('Months')
# Out:
# Text(0.5,0,'Months')

# %%
####deficit due to salinity
beta=0.7*10**-3
alpha=0.2*10**-3

deltaS=(alpha*deficit)/beta

# %%
plt.plot(deltaS) #g/kg
plt.axhline(0,linestyle='--',c='Grey')
plt.ylabel('Freshwater flux [kg/g]')
plt.xlabel('Months')
# Out:
# Text(0.5,0,'Months')

# %%
#### Change in ML temperature in upper 100m during 1 week
week_time=24*7*3600
Q=200*week_time
delta_T=Q/(cp*dens*100)

# %%
print('Change in temperature (oC) in upper 100m during 1 week = {:0.2f}'.format(delta_T))
# Out:
# Change in temperature (oC) in upper 100m during 1 week = 0.28

# %%
#### Change in ML temperature in upper 5m during 1 week (expected to be much greater)
delta_T=Q/(cp*dens*5)

# %%
print('Change in temperature (oC) in upper 5m during 1 week = {:0.2f}'.format(delta_T))
# Out:
# Change in temperature (oC) in upper 5m during 1 week = 5.60

# %% [markdown]
# Note: A deeper MLD will increase in temperature slower than a shallower MLD
