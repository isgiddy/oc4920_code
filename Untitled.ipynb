# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# %%
data_dir='/home/wizard/Documents/observing_the_ocean/skagerak/data/'

# %%
import xarray as xr

### reanalysis data from
###ftp://podaac-ftp.jpl.nasa.gov/allData/ghrsst/data/L4/GLOB/NAVO/K10_SST/2018/338/
# ds=xr.open_mfdataset(data_dir+'cdas*.nc')
# ds=xr.open_dataset(data_dir+'merged-VIIRS_NPP-NAVO-L2P-v3.0-Lat51.3_60.8-Lon5.3_15.5-20181130000000-20181204235959.subset.nc')
ds=xr.open_mfdataset(data_dir+'virss_subset/subsetted*.nc')
ds.keys()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-6cd4c4389874> in <module>()
#       5 # ds=xr.open_mfdataset(data_dir+'cdas*.nc')
#       6 # ds=xr.open_dataset(data_dir+'merged-VIIRS_NPP-NAVO-L2P-v3.0-Lat51.3_60.8-Lon5.3_15.5-20181130000000-20181204235959.subset.nc')
# ----> 7 ds=xr.open_mfdataset(data_dir+'virss_subset/subsetted*.nc')
#       8 ds.keys()
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, lock, data_vars, coords, autoclose, parallel, **kwargs)
#     636         if concat_dim is _CONCAT_DIM_DEFAULT:
#     637             combined = auto_combine(datasets, compat=compat,
# --> 638                                     data_vars=data_vars, coords=coords)
#     639         else:
#     640             combined = auto_combine(datasets, concat_dim=concat_dim,
#
# ...

# %%
ds.sea_surface_temperature.plot()

# %%
ds.keys()
da=ds.sel(lon=slice(0,20),lat=slice(60,52))
fig=plt.figure(figsize=([10,6]))
da.analysed_sst.plot()

# %%
## create a T/S section of the skagerak
### winds
### ssh
